# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
sns.set()

# %%
df = pd.read_csv('C:\\Users\\version\\Desktop\\Data Science Diploma\\Pandas\\datasets\\ecommerce-purchases.csv')
df.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df.describe().round()
# Out:
#         Credit Card  CC Security Code  Purchase Price
# count  1.000000e+04           10000.0         10000.0
# mean   2.341374e+15             907.0            50.0
# std    2.256103e+15            1590.0            29.0
# min    6.040186e+10               0.0             0.0
# 25%    3.056322e+13             280.0            25.0
# 50%    8.699942e+14             548.0            51.0
# 75%    4.492298e+15             816.0            76.0
# max    6.012000e+15            9993.0           100.0

# %%
df.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.rename(columns={'Address':'address',
                   'Lot':'lot',
                   'AM or PM':'am_or_pm',
                   'Browser Info':'browser_info',
                   'Company':'company',
                   'Credit Card':'credit_card',
                   'CC Exp Date':'cc_exp_date',
                   'CC Security Code':'cc_security_code',
                   'CC Provider':'cc_provider',
                   'Email':'email',
                   'Job':'job',
                   'IP Address':'ip_address',
                   'Language':'language',
                   'Purchase Price':'purchase_price'})
# Out:
#                                                 address    lot am_or_pm  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            browser_info  \
# ...

# %%
df['Language'].str.upper()
# Out:
# 0       EL
# 1       FR
# 2       DE
# 3       ES
# 4       ES
#         ..
# 9995    IT
# 9996    PT
# 9997    EL
# 9998    ES
# 9999    EL
# Name: Language, Length: 10000, dtype: object

# %%
df['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %%
df['Purchase Price'].max()
# Out:
# 99.99

# %%
df['Purchase Price'].min()
# Out:
# 0.0

# %%
df[df['Language'] == 'en'].count()
# Out:
# Address             1098
# Lot                 1098
# AM or PM            1098
# Browser Info        1098
# Company             1098
# Credit Card         1098
# CC Exp Date         1098
# CC Security Code    1098
# CC Provider         1098
# Email               1098
# Job                 1098
# IP Address          1098
# Language            1098
# Purchase Price      1098
# dtype: int64

# %%
df[df['Job'] == 'Energy engineer']
# Out:
#                                                 Address    Lot AM or PM  \
# 193   1010 Mahoney Mills Suite 486\nWest Daniellevie...  70 Fd       AM
# 375        87294 Gregory Springs\nNew Lindsey, PW 61411  72 ff       PM
# 513   50398 Mccoy Rest Suite 597\nSouth Garyborough,...  90 WT       AM
# 1062  20471 Felicia Wells Suite 904\nWest Alexis, GU...  23 Vl       PM
# 1792           0821 Andrew Hill\nVictoriaside, NH 80086  46 dW       AM
# 1991  653 Kelly Junctions Apt. 362\nNorth Gracefurt,...  03 bn       PM
# 2865  92915 Norton Flat\nNorth Jessicachester, MH 04662  44 Oq       AM
# 3417         83761 Craig Cape\nDavistown, MS 39305-3149  97 yo       AM
# 4670  64287 Carroll Garden Apt. 545\nPort Jennifer, ...  47 cE       AM
# 6465   171 Thompson Island\nPort Melaniemouth, NH 61111  17 zD       PM
# 6536           6115 Kerry Light\nGonzalezfurt, MP 12704  91 IE       PM
# 8119                    USNS Johnson\nFPO AA 97880-9580  90 af       AM
# ...

# %%
df['Job'].value_counts()
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
#                                  ..
# Prison officer                    7
# Editor, film/video                6
# Actuary                           6
# Information systems manager       5
# Investment analyst                5
# Name: Job, Length: 623, dtype: int64

# %%
df['Job'].value_counts().max()
# Out:
# 31

# %%
df['Job'].value_counts().idxmax()
# Out:
# 'Interior and spatial designer'

# %%
df['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
df[(df['CC Provider'] == 'American Express') & (df['Purchase Price'] > 95)]
# Out:
#                                                 Address    Lot AM or PM  \
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 280   81060 Dustin Causeway Apt. 503\nPort Danielche...  80 zh       PM
# 372              359 Stanley Coves\nSalasfort, SD 59457  75 Ub       PM
# 677       4855 Peter Bridge\nJohnsonberg, PA 90599-0009  62 Nx       AM
# 766             386 Alisha Unions\nSteelebury, ND 19782  28 pJ       PM
# 1225    916 Amanda Heights\nNew Johnland, CA 52112-8572  09 vg       PM
# 1381  79284 Lisa Mews Suite 069\nKellyborough, CT 71...  45 MR       PM
# 1385  67796 James Keys Suite 656\nSouth Katieshire, ...  06 ia       PM
# 1568       76108 Barker Manors\nEast Amy, PW 49544-5921  82 Qw       AM
# 1727  478 Anita Hill Apt. 766\nAverymouth, FM 50629-...  94 qM       AM
# 2146           557 Barton Harbor\nFuentesport, VI 29961  96 MV       AM
# 2264   040 Ingram Way Suite 602\nEast Matthew, AR 67341  52 WA       AM
# ...

# %%
df[(df['CC Provider'] == 'American Express') & (df['Purchase Price'] > 95)].shape
# Out:
# (39, 14)

# %%
plt.figure(figsize=(12,7))
sns.countplot(x=df['Language'], hue=df['AM or PM'], color='g')
# Out:
# <AxesSubplot:xlabel='Language', ylabel='count'>

# %%
plt.figure(figsize=(12,5))
sns.boxplot(y=df['Purchase Price'], color='c', width=.3)
# Out:
# <AxesSubplot:ylabel='Purchase Price'>

# %%
plt.figure(figsize=(12,7))
ax = sns.barplot(x=df['Language'], y=df['Purchase Price'])

# %%
plt.figure(figsize=(15,7))
ax1 = sns.lineplot(x=df['CC Provider'], y=df['Purchase Price'])
